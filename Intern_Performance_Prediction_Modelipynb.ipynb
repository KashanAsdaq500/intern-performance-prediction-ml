# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Feature Importance nikalna
importance = model.feature_importances_

# Graph banana
plt.figure(figsize=(8,5))
plt.bar(['Task_Time','Feedback_Rating','Attendance','Tasks_Completed'], importance)

plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Feature Importance of Intern Performance Prediction Model')

plt.show()
